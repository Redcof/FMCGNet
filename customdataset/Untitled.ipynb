# %%
import pandas as pd
import numpy as np

file = "atz/atz_patch_dataset__3_128_27_v3_10%_30_99%_multiple_refbox.csv"

# %%
ls
# Out:
# Untitled.ipynb  atz/

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    Unnamed: 0                                     image  threat_present  \
# 0           0  S_P_M5_MD_F_W_SS_V_W_back_0906085926.jpg               1
# 1           1  S_P_M5_MD_F_W_SS_V_W_back_0906085926.jpg               1
# 2           2  S_P_M5_MD_F_W_SS_V_W_back_0906085926.jpg               1
# 3           3  S_P_M5_MD_F_W_SS_V_W_back_0906085926.jpg               1
# 4           4  S_P_M5_MD_F_W_SS_V_W_back_0906085926.jpg               1
#
#   front_back  patch_id  label label_txt global_x1y1x2y2 relative_x1y1x2y2  \
# 0       back         0      0   NORMAL0             NaN               NaN
# 1       back         1      0   NORMAL0             NaN               NaN
# 2       back         2      0   NORMAL0             NaN               NaN
# 3       back         3      0   NORMAL0             NaN               NaN
# 4       back         4      0   NORMAL0             NaN               NaN
#
#    anomaly_size              x1x2y1y2 subject_gender subject_id
# ...

# %%
df = df[df['relative_x1y1x2y2'].notna()]

# %%
df.sort_values(['image', 'label_txt'])

# %%
df.sort_values(['image', 'label_txt'])[df['image'] == 'D_P_F1_CK_F_LA_WB_F_S_front_0907140855.jpg']
# Out:
# /var/folders/4w/d_tk0h2x7cgbl6q1vqw8dv6c0000gq/T/ipykernel_1647/2082584023.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.sort_values(['image', 'label_txt'])[df['image'] == 'D_P_F1_CK_F_LA_WB_F_S_front_0907140855.jpg']
#        Unnamed: 0                                       image  threat_present  \
# 36932       36932  D_P_F1_CK_F_LA_WB_F_S_front_0907140855.jpg               1
# 36935       36935  D_P_F1_CK_F_LA_WB_F_S_front_0907140855.jpg               1
# 36937       36937  D_P_F1_CK_F_LA_WB_F_S_front_0907140855.jpg               1
# 36940       36940  D_P_F1_CK_F_LA_WB_F_S_front_0907140855.jpg               1
#
#       front_back  patch_id  label label_txt       global_x1y1x2y2  \
# 36932      front         5     13        CK  (269, 173, 315, 243)
# 36935      front         8     13        CK  (269, 173, 315, 243)
# 36937      front        10     11        WB  (155, 375, 194, 495)
# ...
